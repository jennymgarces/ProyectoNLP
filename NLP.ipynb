# %%
from pymongo import MongoClient

# %%
#Step 1: Connect to MongoDB - Note: Change connection string as needed
client = MongoClient('mongodb+srv://admin:admin@clusternpl-iizwz.mongodb.net/test?retryWrites=true&w=majority')
#Use database
db=client['nlpdata']
# 
#collection
collection = db['preguntasFrecuentes']
for x in collection.find():
  print(x['question'])
# Out:
# ¿Qué horario tiene el centro de Proyección Social y el Instituto de Familia y Vida en Bucaramanga? y ¿Dónde están ubicados?
# ¿La carrera se Sistemas e Informática tiene demanda laboral?
# ¿Qué puntaje debo obtener en las Pruebas Saber Pro para ingresara a la Faculta de Ingeniería de Sistemas e Informática?
# ¿Si estudio otro programa académico, me homologan para obtener doble titulación con ingeniería de Sistemas e informática?
# ¿Cuáles son las áreas de desempeño del ingeniero ambiental?
# ¿Se homologan asignaturas cuando el aspirante es graduado como tecnólogo ambiental?
# ¿La Facultad facilita el desarrollo de prácticas empresariales?
# ¿Se programan salidas técnicas?
# ¿Se homologan asignaturas cuando el aspirante es graduado como tecnólogo en áreas de la Ingeniería de Sistemas y afines?
# ¿Cuáles son las actividades que podrá desempeñar el Ingeniero de Sistemas e Informática?
# ¿Se programan salidas técnicas?
# ¿La Facultad facilita el desarrollo de prácticas empresariales?
# ...
